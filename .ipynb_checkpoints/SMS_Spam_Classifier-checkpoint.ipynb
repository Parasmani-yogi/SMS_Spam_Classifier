# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv(r"spam.csv", encoding='latin1')

# %%
df.head()
# Out:
#      v1                                                 v2 Unnamed: 2  \
# 0   ham  Go until jurong point, crazy.. Available only ...        NaN
# 1   ham                      Ok lar... Joking wif u oni...        NaN
# 2  spam  Free entry in 2 a wkly comp to win FA Cup fina...        NaN
# 3   ham  U dun say so early hor... U c already then say...        NaN
# 4   ham  Nah I don't think he goes to usf, he lives aro...        NaN
#
#   Unnamed: 3 Unnamed: 4
# 0        NaN        NaN
# 1        NaN        NaN
# 2        NaN        NaN
# 3        NaN        NaN
# 4        NaN        NaN

# %%
df.shape
# Out:
# (5572, 5)

# %% [markdown]
# # Step-by-Step Process
# * 1. Data cleaning
# * 2. Expolaratory data anaylysis (EDA)
# * 3. Text Preprocessing
# * 4. Model building
# * 5. Evaluation
# * 6. Improvement
# * 7. Website
# * 8. Deploy

# %% [markdown]
# # **Step 1 - Data Cleaning**

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5572 entries, 0 to 5571
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   v1          5572 non-null   object
#  1   v2          5572 non-null   object
#  2   Unnamed: 2  50 non-null     object
#  3   Unnamed: 3  12 non-null     object
#  4   Unnamed: 4  6 non-null      object
# dtypes: object(5)
# memory usage: 217.8+ KB

# %%
# drop last 3 columns
df.drop(columns=['Unnamed: 2','Unnamed: 3','Unnamed: 4'],inplace=True)

# %%
df.sample(5)
# Out:
#        v1                                                 v2
# 4687  ham           Hmmm.but you should give it on one day..
# 151   ham  Yup i thk cine is better cos no need 2 go down...
# 5458  ham                             Sorry, I'll call later
# 711   ham  It just seems like weird timing that the night...
# 2187  ham        Oh god. I'm gonna Google nearby cliffs now.

# %%
# Renaming the cols
df.rename(columns={'v1':'target','v2':'text'},inplace=True)

# %%
df.sample(5)
# Out:
#      target                                               text
# 4496    ham                                                 Ok
# 3209    ham  She said,'' do u mind if I go into the bedroom...
# 5528    ham  Its just the effect of irritation. Just ignore it
# 1851    ham  Dunno da next show aft 6 is 850. Toa payoh got...
# 2681    ham                        I'm on da bus going home...

# %%
df['target'].value_counts()
# Out:
# target
# ham     4825
# spam     747
# Name: count, dtype: int64

# %%
plt.figure(figsize=(8,6))

df['target'].value_counts().plot.bar(color = ["green","blue"])
plt.title('Total number of ham and spam in the dataset')
plt.show()

# %%
from sklearn.preprocessing import LabelEncoder

# %%
target_encoder = LabelEncoder()

# %%
df['target'] = target_encoder.fit_transform(df['target'])
# ham --> 0
# spam --> 1

# %%
df.sample(5)
# Out:
#       target                                               text
# 1448       1  As a registered optin subscriber ur draw 4 å£1...
# 1517       1  Our brand new mobile music service is now live...
# 3198       0    No de.am seeing in online shop so that i asked.
# 5251       0  Yeah work is fine, started last week, all the ...
# 5437       0                       Am slow in using biola's fne

# %%
# check for missing values
df.isnull().sum()
# Out:
# target    0
# text      0
# dtype: int64

# %%
# check for missing values
df.duplicated().sum()
# Out:
# np.int64(403)

# %%
# remove duplicate
df = df.drop_duplicates(keep='first')

# %%
df
# Out:
#       target                                               text
# 0          0  Go until jurong point, crazy.. Available only ...
# 1          0                      Ok lar... Joking wif u oni...
# 2          1  Free entry in 2 a wkly comp to win FA Cup fina...
# 3          0  U dun say so early hor... U c already then say...
# 4          0  Nah I don't think he goes to usf, he lives aro...
# ...      ...                                                ...
# 5567       1  This is the 2nd time we have tried 2 contact u...
# 5568       0              Will Ì_ b going to esplanade fr home?
# 5569       0  Pity, * was in mood for that. So...any other s...
# 5570       0  The guy did some bitching but I acted like i'd...
# 5571       0                         Rofl. Its true to its name
#
# [5169 rows x 2 columns]

# %%
df.shape
# Out:
# (5169, 2)

# %% [markdown]
# # **Step 2 - Exploratory Data Analysis(EDA)**

# %%
df['target'].value_counts()
# Out:
# target
# 0    4516
# 1     653
# Name: count, dtype: int64

# %%
plt.pie(df['target'].value_counts(),labels=['ham','spam'],autopct="%0.2f")
plt.show()

# %%
# here data is imblanced

# %%
import nltk
nltk.download('punkt')
nltk.download('punkt_tab')
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\HP\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package punkt_tab to
# [nltk_data]     C:\Users\HP\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\HP\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
df['num_characters'] = df['text'].apply(len)

# %%
df.head()
# Out:
#    target                                               text  num_characters
# 0       0  Go until jurong point, crazy.. Available only ...             111
# 1       0                      Ok lar... Joking wif u oni...              29
# 2       1  Free entry in 2 a wkly comp to win FA Cup fina...             155
# 3       0  U dun say so early hor... U c already then say...              49
# 4       0  Nah I don't think he goes to usf, he lives aro...              61

# %%
# number of words
df['num_words'] = df['text'].apply(lambda x:len(nltk.word_tokenize(x)))

# %%
df.head()
# Out:
#    target                                               text  num_characters  \
# 0       0  Go until jurong point, crazy.. Available only ...             111
# 1       0                      Ok lar... Joking wif u oni...              29
# 2       1  Free entry in 2 a wkly comp to win FA Cup fina...             155
# 3       0  U dun say so early hor... U c already then say...              49
# 4       0  Nah I don't think he goes to usf, he lives aro...              61
#
#    num_words
# 0         24
# 1          8
# 2         37
# 3         13
# 4         15

# %%
df['num_sentences'] = df['text'].apply(lambda x:len(nltk.sent_tokenize(x)))

# %%
df.head()
# Out:
#    target                                               text  num_characters  \
# 0       0  Go until jurong point, crazy.. Available only ...             111
# 1       0                      Ok lar... Joking wif u oni...              29
# 2       1  Free entry in 2 a wkly comp to win FA Cup fina...             155
# 3       0  U dun say so early hor... U c already then say...              49
# 4       0  Nah I don't think he goes to usf, he lives aro...              61
#
#    num_words  num_sentences
# 0         24              2
# 1          8              2
# 2         37              2
# 3         13              1
# 4         15              1

# %%
df[['num_characters','num_words','num_sentences']].describe()
# Out:
#        num_characters    num_words  num_sentences
# count     5169.000000  5169.000000    5169.000000
# mean        78.977945    18.455794       1.965564
# std         58.236293    13.324758       1.448541
# min          2.000000     1.000000       1.000000
# 25%         36.000000     9.000000       1.000000
# 50%         60.000000    15.000000       1.000000
# 75%        117.000000    26.000000       2.000000
# max        910.000000   220.000000      38.000000

# %%
# ham messages
df[df['target'] == 0][['num_characters','num_words','num_sentences']].describe()
# Out:
#        num_characters    num_words  num_sentences
# count     4516.000000  4516.000000    4516.000000
# mean        70.459256    17.123782       1.820195
# std         56.358207    13.493970       1.383657
# min          2.000000     1.000000       1.000000
# 25%         34.000000     8.000000       1.000000
# 50%         52.000000    13.000000       1.000000
# 75%         90.000000    22.000000       2.000000
# max        910.000000   220.000000      38.000000

# %%
# spam messages
df[df['target'] == 1][['num_characters','num_words','num_sentences']].describe()
# Out:
#        num_characters   num_words  num_sentences
# count      653.000000  653.000000     653.000000
# mean       137.891271   27.667688       2.970904
# std         30.137753    7.008418       1.488425
# min         13.000000    2.000000       1.000000
# 25%        132.000000   25.000000       2.000000
# 50%        149.000000   29.000000       3.000000
# 75%        157.000000   32.000000       4.000000
# max        224.000000   46.000000       9.000000

# %%
plt.figure(figsize=(12,6))
sns.histplot(df[df['target']==0]['num_characters'],label='ham')
sns.histplot(df[df['target']==1]['num_characters'],color='red',label='spam')
plt.legend()

# %% [markdown]
# * Spam messages typically contain significantly more characters than ham messages, creating a clear visual distinction in the distribution. This length difference helps in identifying spam more accurately. Messages exceeding ~120 characters are more likely to be spam, making num_characters a strong predictive feature. Such patterns discovered through EDA can greatly improve model performance.

# %%
plt.figure(figsize=(12,6))
sns.histplot(df[df['target']==0]['num_words'],label='ham')
sns.histplot(df[df['target']==1]['num_words'],color='red',label='spam')
plt.legend()

# %% [markdown]
# * Spam messages usually contain more words, often twice as many as ham messages. While ham messages are short and tightly packed around 10–15 words, spam messages are longer and more spread out. This clear difference makes num_words a valuable feature for spam detection.

# %%
sns.pairplot(df,hue='target')
# 0 --> ham
# 1 --> spam

# %%
sns.heatmap(df.corr(numeric_only=True),annot=True)
# Out:
# <Axes: >

# %% [markdown]
# # **Step 3 - Data Peprocessing**
# * Lower Case
# * Tokenization
# * Removing special characters
# * Removing stop words and punctuation
# * Stemming

# %%
from nltk.corpus import stopwords
import string

# %%
from nltk.stem.porter import PorterStemmer
ps = PorterStemmer()

# %%
def transform_text(text):
    
    #  Converts everything to lowercase (e.g., "Hello" → "hello").
    text = text.lower()

    # Tokenizes the text — splits it into a list of words and punctuations.
    # Example: "hello! how are you?" → ['hello', '!', 'how', 'are', 'you', '?']
    text = nltk.word_tokenize(text)

    y = []
    for i in text:
        if i.isalnum():
          y.append(i)    
    text = y[:]
    y.clear()

    # Removes stopwords (like: the, is, and, in, to, etc.)
    for i in text:
        if i not in stopwords.words('english') and i not in string.punctuation:
            y.append(i)

    text = y[:]
    y.clear()
    for i in text:
        y.append(ps.stem(i))
    return " ".join(y)

# %%
transform_text("I'm gonna be home soon and i don't want to talk about this stuff anymore tonight, k? I've cried enough today.")
# Out:
# 'gon na home soon want talk stuff anymor tonight k cri enough today'

# %%
ps.stem('played')
# Out:
# 'play'

# %%
df['transformed_text'] = df['text'].apply(transform_text)

# %%
df.head()
# Out:
#    target                                               text  num_characters  \
# 0       0  Go until jurong point, crazy.. Available only ...             111
# 1       0                      Ok lar... Joking wif u oni...              29
# 2       1  Free entry in 2 a wkly comp to win FA Cup fina...             155
# 3       0  U dun say so early hor... U c already then say...              49
# 4       0  Nah I don't think he goes to usf, he lives aro...              61
#
#    num_words  num_sentences                                   transformed_text
# 0         24              2  go jurong point crazi avail bugi n great world...
# 1          8              2                              ok lar joke wif u oni
# 2         37              2  free entri 2 wkli comp win fa cup final tkt 21...
# 3         13              1                u dun say earli hor u c alreadi say
# 4         15              1               nah think goe usf live around though

# %%
from wordcloud import WordCloud
wc = WordCloud(width=500,height=500,min_font_size=10,background_color='white')

# %%
spam_wc = wc.generate(df[df['target'] == 1]['transformed_text'].str.cat(sep=" "))

# %%
plt.figure(figsize=(15,6))
plt.imshow(spam_wc)

# %%
ham_wc = wc.generate(df[df['target'] == 0]['transformed_text'].str.cat(sep=" "))

# %%
plt.figure(figsize=(15,6))
plt.imshow(ham_wc)

# %%
spam_corpus = []
for msg in df[df['target']==1]['transformed_text'].tolist():
    for word in msg.split():
        spam_corpus.append(word)

# %%
 len(spam_corpus)
# Out:
# 9939

# %%
from collections import Counter
spam_words_count = Counter(spam_corpus).most_common(30)
df_spam_words = pd.DataFrame(spam_words_count, columns=['word', 'count'])
df_spam_words.head()
# Out:
#    word  count
# 0  call    320
# 1  free    191
# 2     2    155
# 3   txt    141
# 4  text    122

# %%
plt.figure(figsize=(10,6))
sns.barplot(data=df_spam_words,x='word', y='count',palette='coolwarm')
plt.xticks(rotation=90)
plt.show()
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_8568\2383149684.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=df_spam_words,x='word', y='count',palette='coolwarm')

# %%
ham_corpus = []
for msg in df[df['target']==0]['transformed_text'].tolist():
    for word in msg.split():
        ham_corpus.append(word)

# %%
 len(ham_corpus)
# Out:
# 35404

# %%
from collections import Counter
ham_words_count = Counter(ham_corpus).most_common(30)
df_ham_words = pd.DataFrame(ham_words_count, columns=['word', 'count'])
df_ham_words.head()
# Out:
#   word  count
# 0    u    883
# 1   go    404
# 2  get    349
# 3   gt    288
# 4   lt    287

# %%
plt.figure(figsize=(10,6))
sns.barplot(data=df_ham_words,x='word', y='count',palette='coolwarm')
plt.xticks(rotation=90)
plt.show()
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_8568\1041707072.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=df_ham_words,x='word', y='count',palette='coolwarm')

# %% [markdown]
# # **Step 4 -Model Building**

# %%
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer

# %%
cv = CountVectorizer()

# %%
tfidf = TfidfVectorizer(max_features=3000)

# %%
X = tfidf.fit_transform(df['transformed_text']).toarray()

# %%
X.shape
# Out:
# (5169, 3000)

# %%
Y = df['target'].values

# %%
Y
# Out:
# array([0, 0, 1, ..., 0, 0, 0], shape=(5169,))

# %%
from sklearn.model_selection import train_test_split

# %%
X_train,X_test,Y_train,Y_test = train_test_split(X,Y,test_size = 0.2,random_state=2)

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from sklearn.naive_bayes import GaussianNB, MultinomialNB,BernoulliNB
from sklearn.tree import DecisionTreeClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.ensemble import RandomForestClassifier 
from sklearn.ensemble import AdaBoostClassifier
from sklearn.ensemble import BaggingClassifier
from sklearn.ensemble import ExtraTreesClassifier
from sklearn.ensemble import GradientBoostingClassifier
from xgboost import XGBClassifier

from sklearn.metrics import accuracy_score,confusion_matrix,precision_score

# %%
lrc = LogisticRegression(solver='liblinear',penalty='l1')
svc = SVC(kernel = 'sigmoid',gamma=1.0)
gnb = GaussianNB()
mnb = MultinomialNB()
bnb = BernoulliNB()
dtc = DecisionTreeClassifier(max_depth = 5)
knc = KNeighborsClassifier()
rfc = RandomForestClassifier(n_estimators=50,random_state=2)
abc = AdaBoostClassifier(n_estimators=50,random_state=2)
bc = BaggingClassifier(n_estimators=50,random_state=2)
etc = ExtraTreesClassifier(n_estimators=50,random_state=2)
gbdt = GradientBoostingClassifier(n_estimators=50,random_state=2)
xgb = XGBClassifier(n_estimators=50,random_state=20)

# %%
clfs = {
    'LRC' : lrc,
    'SVC' : svc,
    'GNB' : gnb,
    'MNB' : mnb,
    'bnb' : bnb,
    'DTC' : dtc,
    'KNC' : knc,
    'RFC' : rfc,
    'AdaBoost' : abc,
    'BgC' : bc,
    'ETC' : etc,
    'GBDT' : gbdt,
    'XGBoost' : xgb
}

# %%
def train_classifier(clf,x_train,y_train,x_test,y_test):
    clf.fit(x_train,y_train)
    y_pred = clf.predict(x_test)
    accuracy = accuracy_score(y_test,y_pred)
    precision = precision_score(y_test,y_pred)
  
    return accuracy, precision

# %% [markdown]
# # **Step 5 - Evaluation**

# %%
accuracy_scores = []
precision_scores = []
for name,clf in clfs.items():
    current_accuracy,current_precision = train_classifier(clf,X_train,Y_train,X_test,Y_test)
    print("\nFor  ", name)
    print("Accuracy : ",current_accuracy)
    print("Precision_score : ",current_precision)

    accuracy_scores.append(current_accuracy)
    precision_scores.append(current_precision)
# Out:
# For   LRC
# Accuracy :  0.9555125725338491
# Precision_score :  0.96
#
# For   SVC
# Accuracy :  0.9758220502901354
# Precision_score :  0.9747899159663865
#
# For   GNB
# Accuracy :  0.874274661508704
# Precision_score :  0.5181818181818182
#
# For   MNB
# Accuracy :  0.9709864603481625
# Precision_score :  1.0
#
# For   bnb
# Accuracy :  0.9835589941972921
# Precision_score :  0.991869918699187
#
# For   DTC
# Accuracy :  0.9313346228239845
# Precision_score :  0.8383838383838383
#
# For   KNC
# Accuracy :  0.9052224371373307
# Precision_score :  1.0
#
# For   RFC
# Accuracy :  0.9738878143133463
# Precision_score :  0.9826086956521739
#
# For   AdaBoost
# Accuracy :  0.9216634429400387
# Precision_score :  0.8202247191011236
#
# For   BgC
# Accuracy :  0.9584139264990329
# Precision_score :  0.8682170542635659
#
# For   ETC
# Accuracy :  0.9748549323017408
# Precision_score :  0.9745762711864406
#
# For   GBDT
# Accuracy :  0.9506769825918762
# ...

# %%
performance_df = pd.DataFrame({'Algorithm':clfs.keys(),'Accuracy':accuracy_scores,'Precision':precision_scores}).sort_values('Precision',ascending=False)

# %%
performance_df
# Out:
#    Algorithm  Accuracy  Precision
# 3        MNB  0.970986   1.000000
# 6        KNC  0.905222   1.000000
# 4        bnb  0.983559   0.991870
# 7        RFC  0.973888   0.982609
# 1        SVC  0.975822   0.974790
# 10       ETC  0.974855   0.974576
# 0        LRC  0.955513   0.960000
# 12   XGBoost  0.968085   0.948718
# 11      GBDT  0.950677   0.930693
# 9        BgC  0.958414   0.868217
# 5        DTC  0.931335   0.838384
# 8   AdaBoost  0.921663   0.820225
# 2        GNB  0.874275   0.518182

# %%
performance_df1 = pd.melt(performance_df, id_vars = "Algorithm")

# %%
performance_df1
# Out:
#    Algorithm   variable     value
# 0        MNB   Accuracy  0.970986
# 1        KNC   Accuracy  0.905222
# 2        bnb   Accuracy  0.983559
# 3        RFC   Accuracy  0.973888
# 4        SVC   Accuracy  0.975822
# 5        ETC   Accuracy  0.974855
# 6        LRC   Accuracy  0.955513
# 7    XGBoost   Accuracy  0.968085
# 8       GBDT   Accuracy  0.950677
# 9        BgC   Accuracy  0.958414
# 10       DTC   Accuracy  0.931335
# 11  AdaBoost   Accuracy  0.921663
# 12       GNB   Accuracy  0.874275
# 13       MNB  Precision  1.000000
# 14       KNC  Precision  1.000000
# 15       bnb  Precision  0.991870
# 16       RFC  Precision  0.982609
# 17       SVC  Precision  0.974790
# 18       ETC  Precision  0.974576
# 19       LRC  Precision  0.960000
# 20   XGBoost  Precision  0.948718
# 21      GBDT  Precision  0.930693
# 22       BgC  Precision  0.868217
# 23       DTC  Precision  0.838384
# 24  AdaBoost  Precision  0.820225
# 25       GNB  Precision  0.518182

# %%
sns.catplot(x="Algorithm",y='value',hue='variable',data=performance_df1,kind='bar',height=5)
plt.ylim(0.5,1.0)
plt.xticks(rotation='vertical')
plt.show()

# %% [markdown]
# # **Step 6 - Model Improvement**

# %%
# change the max_features parameter of tfidf
temp_df_max_ft_3000 = pd.DataFrame({'Algorithm':clfs.keys(),'Accuracy_max_ft_3000':accuracy_scores,'Precision_max_ft_3000':precision_scores}).sort_values('Precision_max_ft_3000',ascending=False)

# %%
new_df_max_ft_300 = performance_df.merge(temp_df_max_ft_3000,on='Algorithm')

# %%
new_df_max_ft_300
# Out:
#    Algorithm  Accuracy  Precision  Accuracy_max_ft_3000  Precision_max_ft_3000
# 0        MNB  0.970986   1.000000              0.970986               1.000000
# 1        KNC  0.905222   1.000000              0.905222               1.000000
# 2        bnb  0.983559   0.991870              0.983559               0.991870
# 3        RFC  0.973888   0.982609              0.973888               0.982609
# 4        SVC  0.975822   0.974790              0.975822               0.974790
# 5        ETC  0.974855   0.974576              0.974855               0.974576
# 6        LRC  0.955513   0.960000              0.955513               0.960000
# 7    XGBoost  0.968085   0.948718              0.968085               0.948718
# 8       GBDT  0.950677   0.930693              0.950677               0.930693
# 9        BgC  0.958414   0.868217              0.958414               0.868217
# 10       DTC  0.931335   0.838384              0.931335               0.838384
# ...

# %%
# change the max_features parameter of tfidf# Add num_characters , num_words,num_sentences in 
temp_df_Add_col = pd.DataFrame({'Algorithm':clfs.keys(),'Accuracy_Add_col':accuracy_scores,'Precision_Add_col':precision_scores}).sort_values('Precision_Add_col',ascending=False)

# %%
new_df_Add_col = new_df_max_ft_300.merge(temp_df_Add_col,on='Algorithm')

# %%
new_df_Add_col
# Out:
#    Algorithm  Accuracy  Precision  Accuracy_max_ft_3000  \
# 0        MNB  0.970986   1.000000              0.970986
# 1        KNC  0.905222   1.000000              0.905222
# 2        bnb  0.983559   0.991870              0.983559
# 3        RFC  0.973888   0.982609              0.973888
# 4        SVC  0.975822   0.974790              0.975822
# 5        ETC  0.974855   0.974576              0.974855
# 6        LRC  0.955513   0.960000              0.955513
# 7    XGBoost  0.968085   0.948718              0.968085
# 8       GBDT  0.950677   0.930693              0.950677
# 9        BgC  0.958414   0.868217              0.958414
# 10       DTC  0.931335   0.838384              0.931335
# 11  AdaBoost  0.921663   0.820225              0.921663
# 12       GNB  0.874275   0.518182              0.874275
#
#     Precision_max_ft_3000  Accuracy_Add_col  Precision_Add_col
# 0                1.000000          0.970986           1.000000
# ...

# %%
# use VotingClassifier 
svc = SVC(kernel='sigmoid',gamma=1.0,probability=True)
mnb = MultinomialNB()
etc = ExtraTreesClassifier(n_estimators=50,random_state=2)

# %%
from sklearn.ensemble import VotingClassifier
voting = VotingClassifier(estimators = [('svm',svc),('nb',mnb),('et',etc)],voting='soft')

# %%
voting.fit(X_train,Y_train)
# Out:
# VotingClassifier(estimators=[('svm',
#                               SVC(gamma=1.0, kernel='sigmoid',
#                                   probability=True)),
#                              ('nb', MultinomialNB()),
#                              ('et',
#                               ExtraTreesClassifier(n_estimators=50,
#                                                    random_state=2))],
#                  voting='soft')

# %%
y_pred_voting = voting.predict(X_test)

# %%
print("Accuracy using VotingClassifier :",accuracy_score(Y_test,y_pred_voting))
print("Precision using VotingClassifier  :",precision_score(Y_test,y_pred_voting))
# Out:
# Accuracy using VotingClassifier : 0.9796905222437138
# Precision using VotingClassifier  : 0.9834710743801653

# %%
# Applying stacking
from sklearn.ensemble import StackingClassifier

# %%
estimators=[('svm', svc), ('nb', mnb), ('et', etc)]
final_estimator=RandomForestClassifier()

# %%
clf = StackingClassifier(estimators=estimators, final_estimator=final_estimator)

# %%
clf.fit(X_train,Y_train)
y_pred = clf.predict(X_test)
print("Accuracy",accuracy_score(Y_test,y_pred))
print("Precision",precision_score(Y_test,y_pred))
# Out:
# Accuracy 0.9787234042553191
# Precision 0.9393939393939394

# %%
# Final Model

MNB = MultinomialNB()
MNB.fit(X_train, Y_train)
y_pred_MNB = MNB.predict(X_test)
print("Accuracy",accuracy_score(Y_test,y_pred_MNB))
print("Precision",precision_score(Y_test,y_pred_MNB))
# Out:
# Accuracy 0.9709864603481625
# Precision 1.0

# %%
import pickle

# %%
pickle.dump(tfidf,open('vectorix=zer.pkl','wb'))
pickle.dump(MNB,open('model.pkl','wb'))
